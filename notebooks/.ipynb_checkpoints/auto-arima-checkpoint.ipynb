# %%
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
import pmdarima as pm

import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np


plt.style.use("ggplot")

# %%
def parse_month(x):
    year = int(x.split("-")[0]) + 2000
    month = int(x.split("-")[1])
    day = 1
    return datetime.date(day=day,month=month,year=year)
df = pd.read_csv("../data/shampoo.csv")
df.Sales = df.Sales.astype(float)
df.Month = df.Month.apply(parse_month)
df = df.set_index("Month")

df.Sales = df.Sales.rolling(2).mean()
df = df.dropna()

# %%
df.plot(figsize=(12,4), linewidth=3, marker="o")

train = df.Sales.values[0:30]
test = df.Sales.values[30:-1]

# %%
stepwise_fit = pm.auto_arima(train, start_p=1, start_q=1,
                             max_p=3, max_q=3, m=12,
                             start_P=0, seasonal=True,
                             d=1, D=1, trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=190.936, BIC=192.602, Fit time=0.006 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=188.544, BIC=191.877, Fit time=0.114 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=192.896, BIC=195.396, Fit time=0.033 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=187.682, BIC=190.182, Fit time=0.072 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=184.006, BIC=187.339, Fit time=0.093 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=186.117, BIC=188.616, Fit time=0.045 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=185.254, BIC=189.420, Fit time=0.193 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Total fit time: 0.566 seconds

# %%
from sklearn.metrics import median_absolute_error

# %%
MAPE = np.round(median_absolute_error(stepwise_fit.predict(4), test) / test.mean()  * 100, 4)
print(f"Median Absoloute Percent Error: {MAPE}%")
# Out:
# Median Absoloute Percent Error: 7.2891%

# %%
plt.figure(figsize=(12,4))
plt.plot(stepwise_fit.predict_in_sample(), label="Predicted")
plt.plot(train, label"True")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-a92abe676852> in <module>
#       1 plt.figure(figsize=(12,4))
# ----> 2 plt.plot(stepwise_fit.predict_in_sample(), "Predicted")
#       3 plt.plot(train, "True")
#       4 plt.legend()
#
# ~/miniconda3/envs/threeseven/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/miniconda3/envs/threeseven/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/envs/threeseven/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/miniconda3/envs/threeseven/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/miniconda3/envs/threeseven/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340         ret = []
#     341         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 342             linestyle, marker, color = _process_plot_format(tup[-1])
#     343             tup = tup[:-1]
#     344         elif len(tup) == 3:
#
# ~/miniconda3/envs/threeseven/lib/python3.7/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#     116         else:
#     117             raise ValueError(
# --> 118                 'Unrecognized character %c in format string' % c)
#     119         i += 1
#     120
#
# ValueError: Unrecognized character e in format string
